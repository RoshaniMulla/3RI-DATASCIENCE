# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\soft\appdata\local\programs\python\python311\lib\site-packages (5.19.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\soft\appdata\local\programs\python\python311\lib\site-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in c:\users\soft\appdata\local\programs\python\python311\lib\site-packages (from plotly) (23.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from prophet import Prophet
from prophet.plot import plot_components_plotly, plot_plotly

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("daily temp.csv")

# %%
df.head()
# Out:
#        DATE  MinTemp  MaxTemp  AvgTemp  Sunrise  Sunset
# 0  1/1/2014     33.0     46.0     40.0      657    1756
# 1  1/2/2014     35.0     50.0     43.0      657    1756
# 2  1/3/2014     36.0     45.0     41.0      657    1757
# 3  1/4/2014     32.0     41.0     37.0      658    1757
# 4  1/5/2014     24.0     38.0     31.0      658    1758

# %%
df = df[["DATE", "AvgTemp"]]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1825 entries, 0 to 1824
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   DATE     1825 non-null   object
#  1   AvgTemp  1821 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 28.6+ KB

# %%
df["AvgTemp"].fillna(df["AvgTemp"].mean(), inplace=True)

# %%
df["DATE"] = pd.to_datetime(df["DATE"])

# %%
df.head()
# Out:
#         DATE  AvgTemp
# 0 2014-01-01     40.0
# 1 2014-01-02     43.0
# 2 2014-01-03     41.0
# 3 2014-01-04     37.0
# 4 2014-01-05     31.0

# %%
df.columns = ["ds", "y"]

# %%
df.plot(x="ds", y="y", figsize=(16, 4))
plt.show()

# %%
train = df.iloc[:len(df)-365]
test = df.iloc[len(df)-365:]

# %%
train.shape, test.shape
# Out:
# ((1460, 2), (365, 2))

# %%
model = Prophet()

# %%
model.fit(train)
# Out:
# 19:38:38 - cmdstanpy - INFO - Chain [1] start processing
# 19:38:39 - cmdstanpy - INFO - Chain [1] done processing

# %%
train.tail()
# Out:
#              ds     y
# 1455 2017-12-26  44.0
# 1456 2017-12-27  45.0
# 1457 2017-12-28  43.0
# 1458 2017-12-29  43.0
# 1459 2017-12-30  44.0

# %%
future_dates = model.make_future_dataframe(periods=365)

# %%
forecast = model.predict(future_dates)

# %%
forecast.tail()
# Out:
#              ds      trend  yhat_lower  ...  multiplicative_terms_lower  multiplicative_terms_upper       yhat
# 1820 2018-12-26  46.268723   36.640813  ...                         0.0                         0.0  41.381015
# 1821 2018-12-27  46.268103   37.112002  ...                         0.0                         0.0  41.520480
# 1822 2018-12-28  46.267483   37.353699  ...                         0.0                         0.0  41.858839
# 1823 2018-12-29  46.266863   36.631860  ...                         0.0                         0.0  41.478091
# 1824 2018-12-30  46.266242   36.888465  ...                         0.0                         0.0  41.297133
#
# [5 rows x 19 columns]

# %%
forecast[["ds", "yhat", "yhat_lower", "yhat_upper"]]
# Out:
#              ds       yhat  yhat_lower  yhat_upper
# 0    2014-01-01  39.254749   34.863212   43.274917
# 1    2014-01-02  39.574747   35.432895   43.964788
# 2    2014-01-03  40.085611   35.847683   44.404924
# 3    2014-01-04  39.866874   35.506786   43.655348
# 4    2014-01-05  39.835220   35.792226   43.824782
# ...         ...        ...         ...         ...
# 1820 2018-12-26  41.381015   36.640813   45.846056
# 1821 2018-12-27  41.520480   37.112002   45.999260
# 1822 2018-12-28  41.858839   37.353699   46.214284
# 1823 2018-12-29  41.478091   36.631860   46.091143
# 1824 2018-12-30  41.297133   36.888465   45.836425
#
# [1825 rows x 4 columns]

# %%
plot_plotly(model, forecast)

# %%
plot_components_plotly(model, forecast)

# %%
from sklearn.metrics import mean_squared_error

# %%
pred = forecast.iloc[-365:]["yhat"]

# %%
pred
# Out:
# 1460    41.643579
# 1461    41.924529
# 1462    42.007196
# 1463    42.261397
# 1464    42.603750
#           ...
# 1820    41.381015
# 1821    41.520480
# 1822    41.858839
# 1823    41.478091
# 1824    41.297133
# Name: yhat, Length: 365, dtype: float64

# %%
rmse = np.sqrt(mean_squared_error(test["y"], pred))

# %%
rmse
# Out:
# 3.458617763904657

# %%
test["y"].mean()
# Out:
# 46.31183227640992
